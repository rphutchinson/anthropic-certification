# %%
# Install Dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create API Client
from anthropic import Anthropic

client = Anthropic()
model = "anthropic.claude-4-6-sonnet"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    
    return message.content[0].text

# %%
# make the initial list of messages
messages = []

while True:
    user_input = input("> ")
    print(">", user_input)

    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)

    print ("<", answer)
# Out:
# > what is 1+1
# < 1 + 1 = **2**
# > can you multiply this by 4?
# < Sure!
#
# 2 × 4 = **8**
# > give me three words that rhyme with the previous result
# < Here are three words that rhyme with **eight**:
#
# 1. **Gate**
# 2. **Late**
# 3. **Great**
# >
# < It seems like your message only contains a colon. Could you clarify what you'd like me to help you with? 😊
# >
# < It looks like you may have sent an incomplete message. Feel free to ask me anything whenever you're ready! 😊
# >
# < I'm here whenever you're ready to ask a question or have a conversation! 😊
# >
# < No worries, I'm here whenever you need me! Just let me know how I can help. 😊
# >
# < I'm still here! Feel free to type your question or message whenever you're ready. 😊
# >
# < 😊 I'll be here whenever you're ready to chat!
# >
# < 👋 Just let me know when you'd like to continue our conversation!
# > I'm trying to exit
# < Ah, I see! To exit or close the chat, you can simply:
#
# - **Close the browser tab/window**
# - **Close the app** if you're using one
#
# Hope that helps! Goodbye! 👋😊
# >
# < Goodbye! 👋 Have a great day!
