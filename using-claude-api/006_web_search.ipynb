# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5
}


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01YPs5ohA6PU19S58McGE9xw', container=None, content=[TextBlock(citations=None, text='The best exercises for gaining leg muscle are compound movements that work multiple muscle groups simultaneously. Here are the most effective options:\n\n## Top Exercises:\n\n**1. Barbell Back Squats**\n- Often considered the king of leg exercises\n- Targets quads, glutes, hamstrings, and core\n- Allows for progressive overload with heavy weights\n\n**2. Romanian Deadlifts (RDLs)**\n- Excellent for hamstrings and glutes\n- Also strengthens lower back and grip\n\n**3. Bulgarian Split Squats**\n- Unilateral exercise that helps address muscle imbalances\n- Intense quad and glute activation\n- Requires less weight than traditional squats\n\n**4. Leg Press**\n- Great for safely loading heavy weight\n- Primarily targets quads and glutes\n- Good option if you have back issues\n\n**5. Walking Lunges**\n- Functional movement pattern\n- Works quads, glutes, and hamstrings\n- Improves balance and coordination\n\n## Key Principles for Muscle Growth:\n\n- **Progressive overload**: Gradually increase weight, reps, or sets over time\n- **Volume**: Aim for 10-20 sets per week per muscle group\n- **Rep range**: 6-12 reps per set is generally optimal for hypertrophy\n- **Frequency**: Train legs 2-3 times per week\n- **Nutrition**: Ensure adequate protein intake (0.7-1g per pound of body weight)\n- **Recovery**: Allow 48-72 hours between leg sessions\n\nThe "best" exercise ultimately depends on your individual anatomy, goals, and any limitations. Most effective programs include a combination of these movements rather than relying on just one.', type='text')], model='claude-sonnet-4-5', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=2228, output_tokens=392, server_tool_use=None, service_tier='standard', total_tokens=2620))
