# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "anthropic.claude-4-5-haiku"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete. 
In addition to the task itself you should also create solution criteria for each task that will be used to evaluate the quality of the task definition. 

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
        "solution_criteria": "Description of the solution criteria"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution. 
Use only the provided solution criteria to evaluate the solution. When providing reasoning for your 
score, it should only discuss adherence to the solution criteria.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Solution Criteria:
<solution_criteria>
{test_case["solution_criteria"]}
</solution_criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain regex
* Do not add any comments, commentary, or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score+syntax_score)/2
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.833333333333334

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport ipaddress\n\ndef validate_s3_bucket_name(bucket_name: str) -> bool:\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Must be between 3-63 characters\n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    # Must contain only lowercase letters, numbers, hyphens, and periods\n    if not re.match(r'^[a-z0-9.-]+$', bucket_name):\n        return False\n    \n    # Must start and end with a letter or number\n    if not re.match(r'^[a-z0-9].*[a-z0-9]$', bucket_name) and not re.match(r'^[a-z0-9]$', bucket_name):\n        return False\n    \n    # Cannot be formatted as an IP address\n    try:\n        ipaddress.ip_address(bucket_name)\n        return False\n    except ValueError:\n        pass\n    \n    return True\n",
#     "test_case": {
#       "task": "Create a Python function that validates an AWS S3 bucket name according to AWS naming rules: must be between 3-63 characters, contain only lowercase letters, numbers, hyphens, and periods, start and end with a letter or number, and cannot be formatted as an IP address.",
#       "format": "python",
#       "solution_criteria": "Function should return True for valid bucket names like 'my-bucket.example' and 'bucket123', and return False for invalid names like 'My-Bucket' (uppercase), 'my..bucket' (consecutive periods), or '-bucket' (starts with hyphen). Must handle all AWS S3 bucket naming constraints."
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements most AWS S3 naming constraints and handles the key test cases from the criteria ('My-Bucket' rejection, 'bucket123' acceptance, '-bucket' rejection). However, it fails to implement validation for consecutive periods, which is explicitly mentioned in the criteria as a requirement ('my..bucket' should return False). The start/end validation logic works correctly but contains unnecessary redundancy. These issues prevent full compliance with the stated criteria."
#   },
#   {
#     "output": "\n{\n  \"FunctionName\": \"CloudWatchLogsProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Timeout\": 60,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"LOG_LEVEL\": \"INFO\"\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Generate a JSON configuration object for an AWS Lambda function that processes CloudWatch Logs. The configuration should include: function name, runtime (Python 3.11), timeout (60 seconds), memory (256 MB), and an environment variable named LOG_LEVEL set to 'INFO'.",
#       "format": "json",
#       "solution_criteria": "JSON object must be valid and well-formed with all required properties: FunctionName, Runtime, Timeout, MemorySize, and Environment variables. The structure should follow AWS Lambda configuration conventions and be ready for use with AWS CLI or SDKs."
#     },
#     "score": 9.0,
#     "reasoning": "The solution successfully meets the core requirements by including all five specified elements (FunctionName, Runtime, Timeout, MemorySize, and LOG_LEVEL environment variable) in valid JSON format that adheres to AWS Lambda configuration conventions. However, the solution omits the Handler property and IAM Role, which are standard requirements for actual Lambda function deployment, though they were not explicitly requested in the task criteria."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9_-]+$\n",
#     "test_case": {
#       "task": "Create a regular expression that matches valid AWS IAM role ARNs. An IAM role ARN should follow the format: arn:aws:iam::ACCOUNT_ID:role/ROLE_NAME where ACCOUNT_ID is a 12-digit number and ROLE_NAME contains alphanumeric characters, hyphens, and underscores.",
#       "format": "regex",
#       "solution_criteria": "Regex must match valid IAM role ARNs like 'arn:aws:iam::123456789012:role/my-service-role' and 'arn:aws:iam::000000000000:role/MyRole_123', but reject invalid formats like missing account ID, non-numeric account ID, or invalid role name characters."
#     },
#     "score": 9.0,
#     "reasoning": "The regex successfully matches both test cases provided in the criteria: 'arn:aws:iam::123456789012:role/my-service-role' and 'arn:aws:iam::000000000000:role/MyRole_123'. It correctly rejects invalid formats such as missing account IDs, non-numeric account IDs, and invalid role name characters. The solution meets the core requirements specified in the criteria. However, it lacks stricter validation on role name character positioning that real AWS IAM role naming conventions may impose, though this is not explicitly required by the stated criteria."
#   }
# ]
